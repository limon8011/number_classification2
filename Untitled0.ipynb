# %% [markdown]
# import библиотек

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import mnist

# %% [markdown]
# Скачиваем датасет

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1, 784).astype('float32') / 255.0
X_test = X_test.reshape(-1, 784).astype('float32') / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Создание слоев

# %%
layer_size = [784, 128, 64, 10]
weight_list = []
bias_list = []
for i in range(len(layer_size) - 1):
  coff = np.sqrt(2.0 / layer_size[i])
  weights = np.random.randn(layer_size[i], layer_size[i + 1]) * coff
  bias = np.zeros((1, layer_size[i + 1]))
  bias_list.append(bias)
  weight_list.append(weights)

# %% [markdown]
# Создание функций для обучения

# %%
def Relu(x):
  return np.maximum(x, 0)
def Softmax(x):
    max_x = np.max(x, axis=1, keepdims=True)
    exp_x = np.exp(x - max_z)
    return exp_x / np.sum(exp_x, axis=1, keepdims=True)

# %% [markdown]
# Цикл обучения Forward Pass

# %%
def ForwardPass(x, weight_list, bias_list):
